# %% [markdown]
# # To insert image in Jupyter notebook

# %% [markdown]
# ### >> Select Markdown >>  Goto Edit tab  >> select 'insert image'

# %% [markdown]
# ![we-love-python-800-600.webp](attachment:we-love-python-800-600.webp)

# %% [markdown]
# ![Python.png](attachment:Python.png)

# %% [markdown]
# ![Python-Programming-Language-in-Data-Science.png](attachment:Python-Programming-Language-in-Data-Science.png)
